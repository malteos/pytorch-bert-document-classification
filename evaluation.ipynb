# %% [markdown]
# # Build evaluation tables for paper
#
# - Precomputed results must be located in `experiments_output` directory.

# %%
import json
import os
import pickle
import pandas as pd
import numpy as np
import logging
import matplotlib.pyplot as plt

# %%
experiments = {}
out_dir = 'experiments_output'
for name in os.listdir(out_dir):
    if name.startswith('task'):
        if not os.path.exists(os.path.join(out_dir, name, 'report.json')):
            continue
            
        experiments[name] = {}
        
        experiments[name]['task'] = 'a' if name.startswith('task-a') else 'b'
        
        # Load report
        with open(os.path.join(out_dir, name, 'report.json'), 'r') as f:
            experiments[name]['report'] = json.load(f)
         
        if os.path.exists(os.path.join(out_dir, name, 'model_config.json')):
            with open(os.path.join(out_dir, name, 'model_config.json'), 'r') as f:
                experiments[name]['config'] = json.load(f)
            
        if 'author-only' in name:
            with open(os.path.join(out_dir, name, 'report_author_vec_found.json'), 'r') as f:
                experiments[name]['report'] = json.load(f)

# %%
metrics = ['f1-score', 'precision', 'recall']
scores = []

for n, d in experiments.items():
    dd = {
        'name': n,
        'task': d['task'],
    }
    
    for metric in metrics:
        dd[metric] = d['report']['micro avg'][metric] * 100

    scores.append(dd)
    
#scores = [{'name': n, 'task': , 'micro avg f1-score': d['report']['micro avg']['f1-score']}]

df = pd.DataFrame(scores)
df = df.set_index('name')

for metric in metrics:
    df[metric + '_diff'] = 0

# %%
from IPython.display import display

pd.options.display.float_format = '{:,.2f}'.format

def display_task(df, task_id):
    print(f'#### Task {task_id} ####')
    
    df_a = df[df['task'] == task_id]
    for metric in metrics:
        max_val = df_a[metric].max()
        df_a = df_a.assign(**{metric + '_diff': max_val - df_a[metric]})
        
    for metric in metrics:
        print(f'Sorted by {metric}')
        display(df_a.sort_values([metric], ascending=False))

# %%
display_task(df, 'a')
# Out:
# #### Task a ####
# Sorted by f1-score
#                                                     f1-score  precision  \
# name
# task-a__bert-german_manual_author-embedding_aut...     87.20      88.76
# task-a__bert-german_full                               87.12      89.23
# task-a__bert-german_manual_no-embedding                86.90      89.65
# task-a__bert-german_no-manual_embedding                86.84      89.02
# task-a__bert-german_text-only                          86.65      89.65
# task-a__bert-multilingual_text-only                    83.94      86.31
# task-a__baseline                                       77.00      79.00
# task-a__author-only                                    61.99      75.59
#
#                                                     recall task  \
# name
# task-a__bert-german_manual_author-embedding_aut...   85.70    a
# task-a__bert-german_full                             85.11    a
# task-a__bert-german_manual_no-embedding              84.30    a
# task-a__bert-german_no-manual_embedding              84.75    a
# task-a__bert-german_text-only                        83.86    a
# task-a__bert-multilingual_text-only                  81.70    a
# task-a__baseline                                     74.00    a
# task-a__author-only                                  52.54    a
#
#                                                     f1-score_diff  \
# name
# task-a__bert-german_manual_author-embedding_aut...           0.00
# task-a__bert-german_full                                     0.08
# task-a__bert-german_manual_no-embedding                      0.30
# task-a__bert-german_no-manual_embedding                      0.36
# task-a__bert-german_text-only                                0.55
# task-a__bert-multilingual_text-only                          3.26
# task-a__baseline                                            10.20
# task-a__author-only                                         25.21
#
#                                                     precision_diff  \
# name
# task-a__bert-german_manual_author-embedding_aut...            0.89
# task-a__bert-german_full                                      0.42
# task-a__bert-german_manual_no-embedding                       0.00
# task-a__bert-german_no-manual_embedding                       0.63
# task-a__bert-german_text-only                                 0.01
# task-a__bert-multilingual_text-only                           3.34
# task-a__baseline                                             10.65
# task-a__author-only                                          14.07
#
#                                                     recall_diff
# name
# task-a__bert-german_manual_author-embedding_aut...         0.00
# task-a__bert-german_full                                   0.58
# task-a__bert-german_manual_no-embedding                    1.39
# task-a__bert-german_no-manual_embedding                    0.94
# task-a__bert-german_text-only                              1.84
# task-a__bert-multilingual_text-only                        3.99
# task-a__baseline                                          11.70
# task-a__author-only                                       33.16
# Sorted by precision
#                                                     f1-score  precision  \
# name
# task-a__bert-german_manual_no-embedding                86.90      89.65
# task-a__bert-german_text-only                          86.65      89.65
# task-a__bert-german_full                               87.12      89.23
# task-a__bert-german_no-manual_embedding                86.84      89.02
# task-a__bert-german_manual_author-embedding_aut...     87.20      88.76
# task-a__bert-multilingual_text-only                    83.94      86.31
# task-a__baseline                                       77.00      79.00
# task-a__author-only                                    61.99      75.59
#
#                                                     recall task  \
# name
# task-a__bert-german_manual_no-embedding              84.30    a
# task-a__bert-german_text-only                        83.86    a
# task-a__bert-german_full                             85.11    a
# task-a__bert-german_no-manual_embedding              84.75    a
# task-a__bert-german_manual_author-embedding_aut...   85.70    a
# task-a__bert-multilingual_text-only                  81.70    a
# task-a__baseline                                     74.00    a
# task-a__author-only                                  52.54    a
#
#                                                     f1-score_diff  \
# name
# task-a__bert-german_manual_no-embedding                      0.30
# task-a__bert-german_text-only                                0.55
# task-a__bert-german_full                                     0.08
# task-a__bert-german_no-manual_embedding                      0.36
# task-a__bert-german_manual_author-embedding_aut...           0.00
# task-a__bert-multilingual_text-only                          3.26
# task-a__baseline                                            10.20
# task-a__author-only                                         25.21
#
#                                                     precision_diff  \
# name
# task-a__bert-german_manual_no-embedding                       0.00
# task-a__bert-german_text-only                                 0.01
# task-a__bert-german_full                                      0.42
# task-a__bert-german_no-manual_embedding                       0.63
# task-a__bert-german_manual_author-embedding_aut...            0.89
# task-a__bert-multilingual_text-only                           3.34
# task-a__baseline                                             10.65
# task-a__author-only                                          14.07
#
#                                                     recall_diff
# name
# task-a__bert-german_manual_no-embedding                    1.39
# task-a__bert-german_text-only                              1.84
# task-a__bert-german_full                                   0.58
# task-a__bert-german_no-manual_embedding                    0.94
# task-a__bert-german_manual_author-embedding_aut...         0.00
# task-a__bert-multilingual_text-only                        3.99
# task-a__baseline                                          11.70
# task-a__author-only                                       33.16
# Sorted by recall
#                                                     f1-score  precision  \
# name
# task-a__bert-german_manual_author-embedding_aut...     87.20      88.76
# task-a__bert-german_full                               87.12      89.23
# task-a__bert-german_no-manual_embedding                86.84      89.02
# task-a__bert-german_manual_no-embedding                86.90      89.65
# task-a__bert-german_text-only                          86.65      89.65
# task-a__bert-multilingual_text-only                    83.94      86.31
# task-a__baseline                                       77.00      79.00
# task-a__author-only                                    61.99      75.59
#
#                                                     recall task  \
# name
# task-a__bert-german_manual_author-embedding_aut...   85.70    a
# task-a__bert-german_full                             85.11    a
# task-a__bert-german_no-manual_embedding              84.75    a
# task-a__bert-german_manual_no-embedding              84.30    a
# task-a__bert-german_text-only                        83.86    a
# task-a__bert-multilingual_text-only                  81.70    a
# task-a__baseline                                     74.00    a
# task-a__author-only                                  52.54    a
#
#                                                     f1-score_diff  \
# name
# task-a__bert-german_manual_author-embedding_aut...           0.00
# task-a__bert-german_full                                     0.08
# task-a__bert-german_no-manual_embedding                      0.36
# task-a__bert-german_manual_no-embedding                      0.30
# task-a__bert-german_text-only                                0.55
# task-a__bert-multilingual_text-only                          3.26
# task-a__baseline                                            10.20
# task-a__author-only                                         25.21
#
#                                                     precision_diff  \
# name
# task-a__bert-german_manual_author-embedding_aut...            0.89
# task-a__bert-german_full                                      0.42
# task-a__bert-german_no-manual_embedding                       0.63
# task-a__bert-german_manual_no-embedding                       0.00
# task-a__bert-german_text-only                                 0.01
# task-a__bert-multilingual_text-only                           3.34
# task-a__baseline                                             10.65
# task-a__author-only                                          14.07
#
#                                                     recall_diff
# name
# task-a__bert-german_manual_author-embedding_aut...         0.00
# task-a__bert-german_full                                   0.58
# task-a__bert-german_no-manual_embedding                    0.94
# task-a__bert-german_manual_no-embedding                    1.39
# task-a__bert-german_text-only                              1.84
# task-a__bert-multilingual_text-only                        3.99
# task-a__baseline                                          11.70
# task-a__author-only                                       33.16

# %%
display_task(df, 'b')
# Out:
# #### Task b ####
# Sorted by f1-score
#                                          f1-score  precision  recall task  \
# name
# task-b__bert-german_full                    64.70      83.78   52.70    b
# task-b__bert-german_no-manual_embedding     64.41      82.02   53.03    b
# task-b__bert-german_manual_no-embedding     63.96      83.94   51.67    b
# task-b__bert-german_text-only               60.51      83.44   47.47    b
# task-b__bert-multilingual_text-only         54.08      82.63   40.19    b
# task-b__baseline                            45.00      67.00   34.00    b
# task-b__author-only                         32.13      72.39   20.65    b
#
#                                          f1-score_diff  precision_diff  \
# name
# task-b__bert-german_full                          0.00            0.17
# task-b__bert-german_no-manual_embedding           0.29            1.93
# task-b__bert-german_manual_no-embedding           0.74            0.00
# task-b__bert-german_text-only                     4.19            0.50
# task-b__bert-multilingual_text-only              10.62            1.31
# task-b__baseline                                 19.70           16.94
# task-b__author-only                              32.57           11.56
#
#                                          recall_diff
# name
# task-b__bert-german_full                        0.32
# task-b__bert-german_no-manual_embedding         0.00
# task-b__bert-german_manual_no-embedding         1.36
# task-b__bert-german_text-only                   5.56
# task-b__bert-multilingual_text-only            12.83
# task-b__baseline                               19.03
# task-b__author-only                            32.38
# Sorted by precision
#                                          f1-score  precision  recall task  \
# name
# task-b__bert-german_manual_no-embedding     63.96      83.94   51.67    b
# task-b__bert-german_full                    64.70      83.78   52.70    b
# task-b__bert-german_text-only               60.51      83.44   47.47    b
# task-b__bert-multilingual_text-only         54.08      82.63   40.19    b
# task-b__bert-german_no-manual_embedding     64.41      82.02   53.03    b
# task-b__author-only                         32.13      72.39   20.65    b
# task-b__baseline                            45.00      67.00   34.00    b
#
#                                          f1-score_diff  precision_diff  \
# name
# task-b__bert-german_manual_no-embedding           0.74            0.00
# task-b__bert-german_full                          0.00            0.17
# task-b__bert-german_text-only                     4.19            0.50
# task-b__bert-multilingual_text-only              10.62            1.31
# task-b__bert-german_no-manual_embedding           0.29            1.93
# task-b__author-only                              32.57           11.56
# task-b__baseline                                 19.70           16.94
#
#                                          recall_diff
# name
# task-b__bert-german_manual_no-embedding         1.36
# task-b__bert-german_full                        0.32
# task-b__bert-german_text-only                   5.56
# task-b__bert-multilingual_text-only            12.83
# task-b__bert-german_no-manual_embedding         0.00
# task-b__author-only                            32.38
# task-b__baseline                               19.03
# Sorted by recall
#                                          f1-score  precision  recall task  \
# name
# task-b__bert-german_no-manual_embedding     64.41      82.02   53.03    b
# task-b__bert-german_full                    64.70      83.78   52.70    b
# task-b__bert-german_manual_no-embedding     63.96      83.94   51.67    b
# task-b__bert-german_text-only               60.51      83.44   47.47    b
# task-b__bert-multilingual_text-only         54.08      82.63   40.19    b
# task-b__baseline                            45.00      67.00   34.00    b
# task-b__author-only                         32.13      72.39   20.65    b
#
#                                          f1-score_diff  precision_diff  \
# name
# task-b__bert-german_no-manual_embedding           0.29            1.93
# task-b__bert-german_full                          0.00            0.17
# task-b__bert-german_manual_no-embedding           0.74            0.00
# task-b__bert-german_text-only                     4.19            0.50
# task-b__bert-multilingual_text-only              10.62            1.31
# task-b__baseline                                 19.70           16.94
# task-b__author-only                              32.57           11.56
#
#                                          recall_diff
# name
# task-b__bert-german_no-manual_embedding         0.00
# task-b__bert-german_full                        0.32
# task-b__bert-german_manual_no-embedding         1.36
# task-b__bert-german_text-only                   5.56
# task-b__bert-multilingual_text-only            12.83
# task-b__baseline                               19.03
# task-b__author-only                            32.38
